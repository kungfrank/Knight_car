# %% [markdown]
# # Creative Software Project - Take Home Midterm Exam/Assignment
#
# * Objective: this jupyter notebook is intended to evaluate how the students understand the Duckietown repo
#
# Prof. Nick Wang, 2016/11/7

# %% [markdown]
# ## Instructions:
# 1. $ cp assignment1.ipynb assignment1-XXXXXXX.ipynb (XXXXXXX is your name) You also need to add your name, setup, and state the contributions in the setup and contributions section.
# 2. You can already see the desired outputs of each cell, and you need to find the relevant code in the Duckietown repo and reproduce the results.
# 3. Each student needs to submit one to your mentor, via email. Please do not commit your ipynb to repo. Please do not modify assignment1.ipynb.

# %% [markdown]
# ## Setup and Contributions:
#
# Done by: LEONG YIK SHENG (0545126)
#
# VirtualBox 5.1.6 r110634 (Qt5.5.1) on Windows 8
#
# The following classmates contributed to the completion of this assignment:
# - Desmond (Shu Jian Jie): hue range values for hsv_yellow (to better portray the yellow lines in our duckiebot's image)
# - Allen (Ou Yan Hong): dimensions of rectified image

# %% [markdown]
# # Line Detector

# %% [markdown]
# ### 1.Load the image and resize

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("/home/robotvision/track1.jpg")

image_cv = cv2.resize(img,(160,120),interpolation=cv2.INTER_NEAREST)

dst1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.subplot(121),plt.imshow(dst1,cmap = 'brg')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

dst2 = cv2.cvtColor(image_cv,cv2.COLOR_BGR2RGB)
plt.subplot(122),plt.imshow(dst2,cmap = 'brg')
plt.title('Resized Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ### 2.Find the edge (15%)

# %%
# Parameters for Canny, and Hough transform
canny_thresholds = [80,200]
hough_threshold  = 10
hough_min_line_length = 3
hough_max_line_gap = 1

# %%
gray = [128,128,128]
edges = cv2.Canny(image_cv,canny_thresholds[0],canny_thresholds[1])

plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 3-1.Setup HSV space threshold (15%)

# %%
hsv_white1 =  np.array([0,0,150])
hsv_white2 =  np.array([180,100,255])
hsv_yellow1 = np.array([20,50,50])
hsv_yellow2 = np.array([40,255,255])
hsv_red1 =    np.array([0,100,100])
hsv_red2 =    np.array([15,255,255])
hsv_red3 =    np.array([165,100,100])
hsv_red4 =    np.array([180,255,255])

# %% [markdown]
# ### 3-2.Threshold colors in HSV space (15%)

# %%
# Change color space to HSV
hsv = cv2.cvtColor(image_cv, cv2.COLOR_BGR2HSV)

# Find the colour
white = cv2.inRange(hsv, hsv_white1, hsv_white2)
yellow = cv2.inRange(hsv, hsv_yellow1, hsv_yellow2)
red1 = cv2.inRange(hsv, hsv_red1, hsv_red2)
red2 = cv2.inRange(hsv, hsv_red3, hsv_red4)
#red = red1 + red2
red = cv2.bitwise_or(red1, red2)

# Uncomment '#' to plot with color
#x = cv2.cvtColor(yellow, cv2.COLOR_GRAY2BGR)
#x[:,:,2] *= 1
#x[:,:,1] *= 1
#x[:,:,0] *= 0
#x = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)

#y = cv2.cvtColor(red, cv2.COLOR_GRAY2BGR)
#y[:,:,2] *= 1
#y[:,:,1] *= 0
#y[:,:,0] *= 0
#y = cv2.cvtColor(y, cv2.COLOR_BGR2RGB)

plt.subplot(131),plt.imshow(white,cmap = 'gray')
plt.title('White'), plt.xticks([]), plt.yticks([])

plt.subplot(132),plt.imshow(yellow,cmap = 'gray')
#plt.subplot(132),plt.imshow(x,cmap = 'brg')
plt.title('Yellow'), plt.xticks([]), plt.yticks([])

plt.subplot(133),plt.imshow(red,cmap = 'gray')
#plt.subplot(133),plt.imshow(y,cmap = 'brg')
plt.title('Red'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ### 4.Combine Edge and Colors (15%)

# %%
# Find the edges
edge_color_white = cv2.Canny(white, canny_thresholds[0], canny_thresholds[1], apertureSize = 3)
edge_color_yellow = cv2.Canny(yellow, canny_thresholds[0], canny_thresholds[1], apertureSize = 3)
edge_color_red = cv2.Canny(red, canny_thresholds[0], canny_thresholds[1], apertureSize = 3)


#plt.imshow(edge_color_yellow,cmap = 'gray')
#plt.title('Edge Color Y'), plt.xticks([]), plt.yticks([])
plt.subplot(131),plt.imshow(edge_color_white,cmap = 'gray')
plt.title('Edge Color W'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(edge_color_yellow,cmap = 'gray')
plt.title('Edge Color Y'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(edge_color_red,cmap = 'gray')
plt.title('Edge Color R'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ### 5-1.Find the lines (15%)

# %%
# Find the lines
lines_white = cv2.HoughLinesP(edge_color_white, 1, np.pi/180, hough_threshold, np.empty(1), hough_min_line_length, hough_max_line_gap)
lines_yellow = cv2.HoughLinesP(edge_color_yellow, 1, np.pi/180, hough_threshold, np.empty(1), hough_min_line_length, hough_max_line_gap)
lines_red = cv2.HoughLinesP(edge_color_red, 1, np.pi/180, hough_threshold, np.empty(1), hough_min_line_length, hough_max_line_gap)

color = "yellow"
lines = lines_yellow
bw = yellow

if lines is not None:
    lines = np.array(lines[0])
    print "found lines"

else:
    lines = []
    print "no lines"
# Out:
# found lines

# %% [markdown]
# ### Show the lines (yellow)

# %%
image_with_lines = np.copy(dst2)
if len(lines)>0:
    for x1,y1,x2,y2 in lines:
        cv2.line(image_with_lines, (x1,y1), (x2,y2), (0,0,255), 2)
        cv2.circle(image_with_lines, (x1,y1), 2, (0,255,0))
        cv2.circle(image_with_lines, (x2,y2), 2, (255,0,0))
        
plt.imshow(image_with_lines,cmap = 'brg')
plt.title('Line Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 6-1.Normals (15%)

# %%
arr_cutoff = np.array((0, 40, 0, 40))
arr_ratio = np.array((1./160, 1./120, 1./160, 1./120))
        
normals = []
centers = []
if len(lines)>0:
    
    #find the normalized coordinates
    lines_normalized = ((lines + arr_cutoff) * arr_ratio)

    #find the dx dy
    length = np.sum((lines[:, 0:2] -lines[:, 2:4])**2, axis=1, keepdims=True)**0.5
    dx = 1.*(lines[:,3:4]-lines[:,1:2])/length
    dy = 1.*(lines[:,0:1]-lines[:,2:3])/length
    
    #find the center point
    centers = np.hstack([(lines[:,0:1]+lines[:,2:3])/2, (lines[:,1:2]+lines[:,3:4])/2])

    #find the vectors' direction
    x3 = (centers[:,0:1] - 3.*dx).astype('int')
    x3[x3<0]=0
    x3[x3>=160]=160-1

    y3 = (centers[:,1:2] - 3.*dy).astype('int')
    y3[y3<0]=0
    y3[y3>=120]=120-1

    x4 = (centers[:,0:1] + 3.*dx).astype('int')
    x4[x4<0]=0
    x4[x4>=160]=160-1

    y4 = (centers[:,1:2] + 3.*dy).astype('int')
    y4[y4<0]=0
    y4[y4>=120]=120-1
    
    #find the dx dy direction
    flag_signs = (np.logical_and(bw[y3,x3]>0, bw[y4,x4]==0)).astype('int')*2-1
    normals = np.hstack([dx, dy])*flag_signs

    flag = ((lines[:,2]-lines[:,0])*normals[:,1] - (lines[:,3]-lines[:,1])*normals[:,0])>0
    for i in range(len(lines)):
        if flag[i]:
            x1,y1,x2,y2 = lines[i, :]
            lines[i, :] = [x2,y2,x1,y1]

# %% [markdown]
# ### 6-2.Draw the Normals

# %%
image_with_lines = np.copy(dst2)
if len(centers)>0:
    for x,y,dx,dy in np.hstack((centers,normals)):
        x3 = int(x - 2.*dx)
        y3 = int(y - 2.*dy)
        x4 = int(x + 2.*dx)
        y4 = int(y + 2.*dy)
        cv2.line(image_with_lines, (x3,y3), (x4,y4), (0,0,255), 1)
        cv2.circle(image_with_lines, (x3,y3), 1, (0,255,0))
        cv2.circle(image_with_lines, (x4,y4), 1, (255,0,0))
            
plt.subplot(121),plt.imshow(image_with_lines,cmap = 'brg')
plt.title('Line Normals'), plt.xticks([]), plt.yticks([])

image_with_lines = np.copy(dst2)
if len(lines)>0:
    for x1,y1,x2,y2 in lines:
        cv2.line(image_with_lines, (x1,y1), (x2,y2), (0,0,255), 2)
        cv2.circle(image_with_lines, (x1,y1), 2, (0,255,0))
        cv2.circle(image_with_lines, (x2,y2), 2, (255,0,0))
        
plt.subplot(122),plt.imshow(image_with_lines,cmap = 'brg')
plt.title('Line Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 7-1.setup the segment class

# %%
class Vector2D():
    def __init__(self):
        self.x = 0
        self.y = 0  
class Segment():
    def __init__(self):
        self.color = ""
        self.pixels_normalized = np.array([Vector2D(),Vector2D()])
        self.normal = Vector2D()

# %% [markdown]
# ### 7-2.Store in the SegmentList

# %%
segmentMsgList = []

for x1,y1,x2,y2,norm_x,norm_y in np.hstack((lines_normalized,normals)):
    segment = Segment()
    segment.color = color
    segment.pixels_normalized[0].x = x1
    segment.pixels_normalized[0].y = y1
    segment.pixels_normalized[1].x = x2
    segment.pixels_normalized[1].y = y2
    segment.normal.x = norm_x
    segment.normal.y = norm_y

    segmentMsgList.append(segment)  
    
#print segmentMsgList[2].pixels_normalized[1].x

# %% [markdown]
# ### 7.3 Print the SegmentList

# %%
for i in segmentMsgList:
    print (i.pixels_normalized[0].x,i.pixels_normalized[0].y),(i.pixels_normalized[1].x,i.pixels_normalized[1].y)
# Out:
# (0.31875000000000003, 1.0583333333333333) (0.40000000000000002, 1.0083333333333333)
# (0.55625000000000002, 0.80000000000000004) (0.60625000000000007, 0.80000000000000004)
# (0.38750000000000001, 0.83333333333333337) (0.44375000000000003, 0.84999999999999998)
# (0.55625000000000002, 0.7416666666666667) (0.57500000000000007, 0.7416666666666667)
# (0.61250000000000004, 0.77500000000000002) (0.66875000000000007, 0.78333333333333333)
# (0.56874999999999998, 0.8666666666666667) (0.625, 0.8833333333333333)
# (0.58125000000000004, 0.75) (0.60000000000000009, 0.75)
# (0.32500000000000001, 1.075) (0.38750000000000001, 1.0416666666666667)
# (0.41250000000000003, 0.75) (0.45000000000000001, 0.75)
# (0.45625000000000004, 0.79166666666666663) (0.53749999999999998, 0.79166666666666663)
# (0.70625000000000004, 0.80000000000000004) (0.74375000000000002, 0.76666666666666661)
# (0.46875, 0.84166666666666667) (0.51875000000000004, 0.85833333333333328)
# (0.47500000000000003, 1.0) (0.53749999999999998, 0.96666666666666667)
# (0.64375000000000004, 0.80833333333333335) (0.66250000000000009, 0.80000000000000004)
# (0.0, 1.1666666666666667) (0.0625, 1.1499999999999999)
# (0.77500000000000002, 0.82499999999999996) (0.8125, 0.80833333333333335)
# (0.53125, 0.94999999999999996) (0.55000000000000004, 0.94166666666666665)
# (0.45000000000000001, 0.98333333333333328) (0.48125000000000001, 0.96666666666666667)
# (0.41250000000000003, 0.78333333333333333) (0.45000000000000001, 0.78333333333333333)
# (0.55000000000000004, 0.93333333333333335) (0.63750000000000007, 0.89166666666666661)
# (0.13750000000000001, 1.1499999999999999) (0.16250000000000001, 1.1416666666666666)
# (0.15625, 1.125) (0.1875, 1.1083333333333334)
# (0.60625000000000007, 0.7416666666666667) (0.66250000000000009, 0.7416666666666667)
# (0.45625000000000004, 0.84166666666666667) (0.48125000000000001, 0.84999999999999998)
# (0.48125000000000001, 0.8666666666666667) (0.5, 0.8666666666666667)
# (0.45000000000000001, 0.76666666666666661) (0.51250000000000007, 0.75)
# (0.012500000000000001, 1.1916666666666667) (0.050000000000000003, 1.175)
# (0.30000000000000004, 0.82499999999999996) (0.34375, 0.82499999999999996)
# (0.20000000000000001, 1.1083333333333334) (0.23750000000000002, 1.0833333333333333)
# (0.58125000000000004, 0.76666666666666661) (0.61250000000000004, 0.76666666666666661)
# (0.66875000000000007, 0.81666666666666665) (0.75, 0.81666666666666665)
# (0.39375000000000004, 0.82499999999999996) (0.41250000000000003, 0.82499999999999996)
# (0.57500000000000007, 0.8833333333333333) (0.59375, 0.8833333333333333)
# (0.47500000000000003, 0.97499999999999998) (0.50624999999999998, 0.95833333333333337)
# (0.53749999999999998, 0.85833333333333328) (0.5625, 0.85833333333333328)
# (0.50624999999999998, 0.8666666666666667) (0.53749999999999998, 0.875)
# (0.16875000000000001, 1.1416666666666666) (0.24375000000000002, 1.1083333333333334)
# (0.46250000000000002, 1.0) (0.48125000000000001, 0.9916666666666667)
# (0.39375000000000004, 1.0416666666666667) (0.41875000000000001, 1.0249999999999999)
# (0.61875000000000002, 0.90833333333333333) (0.64375000000000004, 0.90000000000000002)
# (0.43125000000000002, 0.83333333333333337) (0.45000000000000001, 0.83333333333333337)
# (0.0, 1.1916666666666667) (0.018750000000000003, 1.1833333333333333)

# %% [markdown]
# # Ground Projection

# %%
lines_normalized, normals


print lines_normalized[0,1],normals[0]
# Out:
# 1.05833333333 [-0.41905818 -0.90795938]

# %% [markdown]
# ### camera parameters

# %%
import cv2
import numpy as np
#camera_matrix = np.array([[1.3e+03, 0., 6.0e+02], [0., 1.3e+03, 4.8e+02], [0., 0., 1.]], dtype=np.float32)
#dist_coeffs = np.array([-2.4-01, 9.5e-02, -4.0e-04, 8.9e-05, 0.], dtype=np.float32)

# Values of homography, intrinsic camera_matrix and dist_coeffs from topbot
homography = np.array([[-5.163285e-05, -7.347755e-05, -0.09228475], [0.0005462526, -1.065234e-05, -0.1912934], [-0.0001214929, -0.004885648, 1]]
)
matrix = np.array([[308.745107860966, 0.0, 334.5906177764699], [0.0, 310.56621075543836, 237.14284056302324],
    [0.0, 0.0, 1.0]])
coeffs = np.array([-0.312784847883155, 0.09142498691095552, -0.00022411455355343017, 0.0019941157593890767,
    0.0])

# %%
pt_img = np.array([[0.5*640],[0.7*480],[1.]])
#print pt_img
G = np.dot(homography,pt_img)
G/=G[2]
print G

pt_img = np.array([[[0.5*640,0.7*480]]])

xy_undistorted = cv2.undistortPoints(pt_img, matrix, coeffs,R=None, P=matrix)
pt_img = np.array([[xy_undistorted[0][0][0]],[xy_undistorted[0][0][1]],[1.]])
#print xy_undistorted
G_rect = np.dot(homography,pt_img)
G_rect/=G_rect[2]
print G_rect
# Out:
# [[ 0.19618583]
#  [ 0.02949753]
#  [ 1.        ]]
# [[ 0.19174547]
#  [ 0.02929129]
#  [ 1.        ]]

# %% [markdown]
# ### Rectify the image (15%)

# %%
from matplotlib import pyplot as plt

origin = cv2.imread("/home/robotvision/track1.jpg")
origin = cv2.resize(origin,(640,480),interpolation=cv2.INTER_NEAREST)

# Undistort image with topbot's calibration
h, w = origin.shape[:2]
newcameramtx, roi = cv2.getOptimalNewCameraMatrix(matrix, coeffs, (w, h), 1, (w, h))

rec_img = cv2.undistort(origin, matrix, coeffs, newcameramtx)

# Crop image
x, y, w, h = roi
rec_img = rec_img[y:y+h, x:x+w]

origin = cv2.cvtColor(origin,cv2.COLOR_BGR2RGB)
plt.subplot(121),plt.imshow(origin,cmap = 'brg')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

rec_img = cv2.cvtColor(rec_img,cv2.COLOR_BGR2RGB)
plt.subplot(122),plt.imshow(rec_img,cmap = 'brg')
plt.title('Rectified Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Duckietown Lane Filter

# %%
import numpy as np
from scipy.stats import multivariate_normal, entropy
from scipy.ndimage.filters import gaussian_filter
from math import floor, atan2, pi, cos, sin, sqrt
import time
from matplotlib import pyplot as plt

# %% [markdown]
# ## Environment Setup

# %%
# constant
WHITE = 0
YELLOW = 1
RED = 2

lanewidth = 0.4
linewidth_white = 0.04
linewidth_yellow = 0.02

# %% [markdown]
# ## Generate Vote (Extra Credit 10% for generating multiple votes from all detected segments)

# %% [markdown]
# #### Setup a line segment
# * left edge of white lane
# * right edge of white lane
# * left edge of yellow lane
# * right edge of white lane

# %%
# right edge of white lane
#p1 = np.array([0.8, 0.24])
#p2 = np.array([0.4, 0.24])
p1 = np.array([lines_normalized[0][0],lines_normalized[0][1]])
p2 = np.array([lines_normalized[0][2],lines_normalized[0][3]]) 
seg_color = YELLOW

# left edge of white lane
#p1 = np.array([0.4, 0.2])
#p2 = np.array([0.8, 0.2])
#seg_color = WHITE

#plt.plot([p1[0], p2[0]], [p1[1], p2[1]], 'ro')
#plt.plot([p1[0], p2[0]], [p1[1], p2[1]])
#plt.ylabel('y')
#plt.axis([0, 5, 0, 5])
#plt.show()

# %% [markdown]
# #### compute d_i, phi_i, l_i

# %%
t_hat = (p2-p1)/np.linalg.norm(p2-p1)
n_hat = np.array([-t_hat[1],t_hat[0]])
d1 = np.inner(n_hat,p1)
d2 = np.inner(n_hat,p2)
l1 = np.inner(t_hat,p1)
l2 = np.inner(t_hat,p2)

print (d1, d2, l1, l2)

if (l1 < 0):
    l1 = -l1;
if (l2 < 0):
    l2 = -l2;
l_i = (l1+l2)/2
d_i = (d1+d2)/2
phi_i = np.arcsin(t_hat[1])
if seg_color == WHITE: # right lane is white
    if(p1[0] > p2[0]): # right edge of white lane
        d_i = d_i - linewidth_white
        print ('right edge of white lane')
    else: # left edge of white lane
        d_i = - d_i
        phi_i = -phi_i
        print ('left edge of white lane')
    d_i = d_i - lanewidth/2

elif seg_color == YELLOW: # left lane is yellow
    if (p2[0] > p1[0]): # left edge of yellow lane
        d_i = d_i - linewidth_yellow
        phi_i = -phi_i
        print ('right edge of yellow lane')
    else: # right edge of white lane
        d_i = -d_i
        print ('right edge of yellow lane')
    d_i =  lanewidth/2 - d_i

    
print (d_i, phi_i, l_i)
# Out:
# (1.0683944396094822, 1.0683944396094822, -0.2832036870451814, -0.18780157752972043)
# right edge of yellow lane
# (-0.84839443960948224, 0.55165498252854739, 0.23550263228745091)

# %% [markdown]
# ### Measurement Likelihood

# %%
# initialize measurement likelihood

d_min = -0.7
d_max = 0.5
delta_d = 0.02
phi_min = -pi/2
phi_max = pi/2
delta_phi = 0.02
d, phi = np.mgrid[d_min:d_max:delta_d, phi_min:phi_max:delta_phi]

measurement_likelihood = np.zeros(d.shape)

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(measurement_likelihood, interpolation='nearest')
fig.colorbar(cax)
plt.ylabel('phi')
plt.xlabel('d')
#ax.set_xticklabels(['']+alpha)
#ax.set_yticklabels(['']+alpha)
plt.show()

# %%
i = floor((d_i - d_min)/delta_d)
j = floor((phi_i - phi_min)/delta_phi)
measurement_likelihood[i,j] = measurement_likelihood[i,j] +  1/(l_i)

print (i, j)

fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(measurement_likelihood, interpolation='nearest')
fig.colorbar(cax)
plt.ylabel('phi')
plt.xlabel('d')
#ax.set_xticklabels(['']+alpha)
#ax.set_yticklabels(['']+alpha)
plt.show()
# Out:
# /home/robotvision/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()
# (-8.0, 106.0)

# %% [markdown]
# ## Bayes' Filter (Extra Credit 10% for integrating Bayes' filter for multiple votes)

# %% [markdown]
# ### 1. Initialize Belief

# %%
print d.shape
beliefRV = np.empty(d.shape)
pos = np.empty(d.shape + (2,))
pos[:,:,0]= d
pos[:,:,1]= phi

print pos.shape
# Out:
# (60, 158)
# (60, 158, 2)

# %%
mean_0 = [0, 0]
cov_0 = [[0.1, 0], [0, 0.01]]

RV = multivariate_normal(mean_0, cov_0)
beliefRV=RV.pdf(pos)

plt.ylabel('phi')
plt.xlabel('d')
plt.contourf(d, phi, beliefRV)
plt.show()

# %% [markdown]
# ### 2.1 Update Belief

# %%
beliefRV=np.multiply(beliefRV+1,measurement_likelihood+1)-1
beliefRV=beliefRV/np.sum(beliefRV)

plt.ylabel('phi')
plt.xlabel('d')
plt.contourf(d, phi, beliefRV)
plt.show()

# %%
maxids = np.unravel_index(beliefRV.argmax(),beliefRV.shape)
print maxids
lanePose_d = d_min + maxids[0] * delta_d
lanePose_phi = phi_min + maxids[1] * delta_phi

print lanePose_d
print lanePose_phi
# Out:
# (35, 79)
# 1.11022302463e-16
# 0.0092036732051
